# %% [markdown]
# # TavilyCrawl Tutorial: Intelligent Web Crawling
#
# ## What We'll Build
#
# In this tutorial, you'll learn how to use TavilyCrawl to intelligently crawl websites using AI-guided instructions. We'll demonstrate:
#
# 1. **Basic Web Crawling** - Crawl a website without specific instructions
# 2. **Instruction-Guided Crawling** - Use natural language to target specific content
# 3. **Results Comparison** - Compare the effectiveness of both approaches
# 4. **Best Practices** - Learn how to write effective crawling instructions
#
# ### Target Website
# We'll crawl the LangChain documentation (https://python.langchain.com/) to find content about AI agents.
#
# ## What is TavilyCrawl?
#
# TavilyCrawl is an intelligent web crawler that uses AI to determine which paths to explore during crawling. It combines AI-powered decision making with parallel processing capabilities.
#
# ### Key Features:
#
# - **AI-Powered Path Selection**: Uses AI to determine which paths to explore
# - **Parallel Processing**: Explores hundreds of paths simultaneously
# - **Advanced Extraction**: Extracts content from dynamically rendered pages
# - **Instruction-Driven**: Follows natural language instructions to guide exploration
# - **Targeted Content**: Returns content tailored for LLM integration and RAG systems
#
# ### Tavily Resources:
# - <a href="https://tavily.com" target="_blank">Official Website</a>
# - <a href="https://docs.tavily.com" target="_blank">API Documentation</a>
# - <a href="https://docs.tavily.com/documentation/api-reference/endpoint/crawl" target="_blank">Crawl API Reference</a>
# - <a href="https://pypi.org/project/langchain-tavily/" target="_blank">LangChain Python Integration</a>
# - <a href="https://app.tavily.com/home?utm_campaign=eden_marco&utm_medium=socials&utm_source=linkedin" target="_blank">Get API Key</a>
#
# This tutorial demonstrates TavilyCrawl by comparing crawl results with and without instructions on the LangChain documentation.
#
# ---

# %% [markdown]
# ## Setup & Installation
#
# First, let's install the required packages and set up our environment.

# %%
# Install required packages
# %pip install langchain-tavily certifi

# For pretty printing and visualization
# %pip install rich pandas
# Out:
# Requirement already satisfied: langchain-tavily in c:\users\mbw2025\anaconda3\lib\site-packages (0.2.18)
# Requirement already satisfied: certifi in c:\users\mbw2025\anaconda3\lib\site-packages (2025.4.26)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-tavily) (3.13.5)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-tavily) (1.2.18)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-tavily) (1.3.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-tavily) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mbw2025\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mbw2025\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.23.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (1.1.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (4.13.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mbw2025\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mbw2025\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mbw2025\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.4.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mbw2025\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-tavily) (4.0.3)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in c:\users\mbw2025\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mbw2025\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\mbw2025\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (2.20.1)
# Requirement already satisfied: anyio in c:\users\mbw2025\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\mbw2025\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\mbw2025\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mbw2025\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.12.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: rich in c:\users\mbw2025\anaconda3\lib\site-packages (13.7.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\mbw2025\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from rich) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from rich) (2.15.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mbw2025\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mbw2025\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mbw2025\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mbw2025\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mbw2025\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\mbw2025\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
import ssl
import json
from typing import Any, Dict, List

import certifi
from langchain_tavily import TavilyCrawl
from rich.console import Console
from rich.panel import Panel
from rich.table import Table
from rich.json import JSON

# Configure SSL context
ssl_context = ssl.create_default_context(cafile=certifi.where())
os.environ["SSL_CERT_FILE"] = certifi.where()
os.environ["REQUESTS_CA_BUNDLE"] = certifi.where()

# Initialize rich console for pretty printing
console = Console()

print("All imports successful!")
# Out:
# All imports successful!

# %% [markdown]
# ## API Key Setup
#
# You'll need a Tavily API key to use TavilyCrawl. Get yours at [https://app.tavily.com/home?utm_campaign=eden_marco&utm_medium=socials&utm_source=linkedin](https://app.tavily.com/home?utm_campaign=eden_marco&utm_medium=socials&utm_source=linkedin).
#
# Set environment variable `TAVILY_API_KEY`

# %%
# Set your Tavily API key here
import getpass

# For Google Colab, you can use getpass for secure input
if 'TAVILY_API_KEY' not in os.environ:
    os.environ['TAVILY_API_KEY'] = getpass.getpass('Enter your Tavily API key: ')

# Alternative: Set directly (uncomment and add your key)
# os.environ["TAVILY_API_KEY"] = "your_tavily_api_key_here"

print("API key set successfully!")
# Out:
# API key set successfully!

# %%
import os
files = os.listdir(".")
if ".env" in files:
    print("✅ Đã thấy file .env")
    # Kiểm tra kích thước file (nếu bằng 0 là file trống)
    print(f"Kích thước file: {os.path.getsize('.env')} bytes")
else:
    print("❌ Không thấy file '.env'. Các file đang có là:", files)
# Out:
# ✅ Đã thấy file .env
# Kích thước file: 587 bytes

# %%
from dotenv import load_dotenv, find_dotenv
import os

# 1. Nạp key trước
load_dotenv(find_dotenv(), override=True)

# 2. Kiểm tra chắc chắn trong code
print(f"Kiểm tra Key: {os.getenv('TAVILY_API_KEY')[:10]}...") 

# 3. Sau đó mới khởi tạo công cụ
from langchain_tavily import TavilyCrawl
tavily_crawl = TavilyCrawl()
# Out:
# Kiểm tra Key: tvly-dev-4...

# %% [markdown]
# ## Initialize TavilyCrawl
#
# Initialize TavilyCrawl and set up target URL for demonstration.

# %%
# Initialize TavilyCrawl
tavily_crawl = TavilyCrawl()

# Target URL: LangChain Documentation
target_url = "https://python.langchain.com/"

console.print(Panel.fit(
    f"Target Website: {target_url}\nCrawler: TavilyCrawl",
    title="Demo Setup",
    border_style="bright_blue"
))

print("TavilyCrawl initialized successfully")
# Out:
# ╭───────────────── Demo Setup ──────────────────╮
# │ Target Website: https://python.langchain.com/ │
# │ Crawler: TavilyCrawl                          │
# ╰───────────────────────────────────────────────╯
# TavilyCrawl initialized successfully

# %% [markdown]
# ## Demo 1: Crawl Without Instructions
#
# Crawl without specific instructions to show baseline behavior on the LangChain documentation.

# %%
# Demo 1: Crawl without instructions
console.print(Panel.fit(
    f"Target: {target_url}\nInstructions: None (baseline crawl)\nMax Depth: 1\nExtract Depth: advanced",
    title="Demo 1: Crawl Without Instructions",
    border_style="blue"
))

console.print("Running TavilyCrawl without instructions...", style="blue")

# Basic crawl without instructions
basic_result = tavily_crawl.invoke({
    "url": target_url,
    "max_depth": 1,
    "extract_depth": "advanced"
})

# Show raw output immediately
console.print(basic_result)

# Extract results for analysis
basic_results = basic_result.get("results", [])
# Out:
# ╭─ Demo 1: Crawl Without Instructions ──╮
# │ Target: https://python.langchain.com/ │
# │ Instructions: None (baseline crawl)   │
# │ Max Depth: 1                          │
# │ Extract Depth: advanced               │
# ╰───────────────────────────────────────╯
# Running TavilyCrawl without instructions...
# {
#     'base_url': 'https://python.langchain.com/',
#     'results': [
#         {
#             'url': 'https://python.langchain.com/',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/$%7BCHAT_APP_URL%7D',
#             'raw_content': '# LangChain overview - Docs by LangChain\n\n[Skip to main
# content](https://python.langchain.com/$%7BCHAT_APP_URL%7D#content-area)\n\nJoin us May 13th & May 14th at
# Interrupt, the Agent Conference by LangChain. [Buy tickets >](https://interrupt.langchain.com/)\n\n[Docs by
# LangChain home page![Image 1: light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 2: dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://python.langchain.com/)![Image 3:
# https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3
# .us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png)Open source\n\nSearch...\n\nCtrl K\n\n*
# [Ask AI](https://chat.langchain.com/)\n*   [GitHub](https://github.com/langchain-ai)\n*   [Try
# LangSmith](https://smith.langchain.com/)\n*   [Try
# LangSmith](https://smith.langchain.com/)\n\nSearch...\n\nNavigation\n\nLangChain overview\n\n[Deep
# Agents](https://python.langchain.com/oss/python/deepagents/overview)[LangChain](https://python.langchain.com/oss/py
# thon/langchain/overview)[LangGraph](https://python.langchain.com/oss/python/langgraph/overview)[Integrations](https
# ://python.langchain.com/oss/python/integrations/providers/overview)[Learn](https://python.langchain.com/oss/python/
# learn)[Reference](https://python.langchain.com/oss/python/reference/overview)[Contribute](https://python.langchain.
# com/oss/python/contributing/overview)\n\nPython\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/overview)\n\n##### Get started\n\n*
# [Install](https://python.langchain.com/oss/python/langchain/install)\n*
# [Quickstart](https://python.langchain.com/oss/python/langchain/quickstart)\n*
# [Changelog](https://docs.langchain.com/oss/python/releases/changelog)\n*
# [Philosophy](https://python.langchain.com/oss/python/langchain/philosophy)\n\n##### Core components\n\n*
# [Agents](https://python.langchain.com/oss/python/langchain/agents)\n*
# [Models](https://python.langchain.com/oss/python/langchain/models)\n*
# [Messages](https://python.langchain.com/oss/python/langchain/messages)\n*
# [Tools](https://python.langchain.com/oss/python/langchain/tools)\n*   [Short-term
# memory](https://python.langchain.com/oss/python/langchain/short-term-memory)\n*
# [Streaming](https://python.langchain.com/oss/python/langchain/streaming)\n*   [Structured
# output](https://python.langchain.com/oss/python/langchain/structured-output)\n\n##### Middleware\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/middleware/overview)\n*   [Prebuilt
# middleware](https://python.langchain.com/oss/python/langchain/middleware/built-in)\n*   [Custom
# middleware](https://python.langchain.com/oss/python/langchain/middleware/custom)\n\n##### Frontend\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/frontend/overview)\n*   Patterns  \n*   Integrations
# \n\n##### Advanced usage\n\n*   [Guardrails](https://python.langchain.com/oss/python/langchain/guardrails)\n*
# [Runtime](https://python.langchain.com/oss/python/langchain/runtime)\n*   [Context
# engineering](https://python.langchain.com/oss/python/langchain/context-engineering)\n*   [Model Context Protocol
# (MCP)](https://python.langchain.com/oss/python/langchain/mcp)\n*
# [Human-in-the-loop](https://python.langchain.com/oss/python/langchain/human-in-the-loop)\n*   Multi-agent  \n*
# [Retrieval](https://python.langchain.com/oss/python/langchain/retrieval)\n*   [Long-term
# memory](https://python.langchain.com/oss/python/langchain/long-term-memory)\n\n##### Agent development\n\n*
# [LangSmith Studio](https://python.langchain.com/oss/python/langchain/studio)\n*   Test  \n*   [Agent Chat
# UI](https://python.langchain.com/oss/python/langchain/ui)\n\n##### Deploy with LangSmith\n\n*
# [Deployment](https://python.langchain.com/oss/python/langchain/deploy)\n*
# [Observability](https://python.langchain.com/oss/python/langchain/observability)\n\nOn this page\n\n*   [Create an
# agent](https://python.langchain.com/$%7BCHAT_APP_URL%7D#create-an-agent)\n*   [Core
# benefits](https://python.langchain.com/$%7BCHAT_APP_URL%7D#core-benefits)\n\n# LangChain overview\n\nCopy
# page\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for any model or
# tool—so you can build agents that adapt as fast as the ecosystem evolves\n\nCopy page\n\n> ## Documentation
# Index\n> \n> \n> Fetch the complete documentation index at:
# [https://docs.langchain.com/llms.txt](https://docs.langchain.com/llms.txt)\n> \n> \n> Use this file to discover all
# available pages before exploring further.\n\nBuild completely custom agents and applications powered by LLMs in
# under 10 lines of code, with integrations for [OpenAI, Anthropic, Google, and
# more](https://python.langchain.com/oss/python/integrations/providers/overview). LangChain provides a prebuilt agent
# architecture and model integrations to help you get started quickly and seamlessly incorporate LLMs into your
# agents and applications.\n\n**LangChain vs. LangGraph vs. Deep Agents**Start with [Deep
# Agents](https://python.langchain.com/oss/python/deepagents/overview) for a “batteries-included” agent with features
# like automatic context compression, a virtual filesystem, and subagent-spawning. Deep Agents are built on LangChain
# [agents](https://python.langchain.com/oss/python/langchain/agents) which you can also use LangChain directly.Use
# [LangGraph](https://python.langchain.com/oss/python/langgraph/overview), our low-level orchestration framework, for
# advanced needs combining deterministic and agentic workflows.\n\n##
# [\u200b](https://python.langchain.com/$%7BCHAT_APP_URL%7D#create-an-agent)\n\n Create an agent\n\nOpenAI\n\nGoogle
# Gemini\n\nClaude (Anthropic)\n\nOpenRouter\n\nFireworks\n\nBaseten\n\nOllama\n\nAzure\n\nAWS
# Bedrock\n\nHuggingFace\n\n```\n# pip install -qU langchain "langchain[openai]"\nfrom langchain.agents import
# create_agent\n\ndef get_weather(city: str) -> str:\n    """Get weather for a given city."""\n    return f"It\'s
# always sunny in {city}!"\n\nagent = create_agent(\n    model="openai:gpt-5.4",\n    tools=[get_weather],\n
# system_prompt="You are a helpful assistant",\n)\n\nresult = agent.invoke(\n    {"messages": [{"role": "user",
# "content": "What\'s the weather in San Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)\n```\n\nSee
# the [Installation instructions](https://python.langchain.com/oss/python/langchain/install) and [Quickstart
# guide](https://python.langchain.com/oss/python/langchain/quickstart) to get started building your own agents and
# applications with LangChain.\n\nUse [LangSmith](https://python.langchain.com/langsmith/home) to trace requests,
# debug agent behavior, and evaluate outputs. Set `LANGSMITH_TRACING=true` and your API key to get started.\n\n##
# [\u200b](https://python.langchain.com/$%7BCHAT_APP_URL%7D#core-benefits)\n\n Core benefits\n\n## [Standard model
# interface Different providers have unique APIs for interacting with models, including the format of responses.
# LangChain standardizes how you interact with models so that you can seamlessly swap providers and avoid lock-in.
# Learn more](https://python.langchain.com/oss/python/langchain/models)\n\n## [Easy to use, highly flexible agent
# LangChain’s agent abstraction is designed to be easy to get started with, letting you build a simple agent in under
# 10 lines of code. But it also provides enough flexibility to allow you to do all the context engineering your heart
# desires. Learn more](https://python.langchain.com/oss/python/langchain/agents)\n\n[![Image 4:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-s
# jd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images
# /brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81) ## Built
# on top of LangGraph LangChain’s agents are built on top of LangGraph. This allows us to take advantage of
# LangGraph’s durable execution, human-in-the-loop support, persistence, and more. Learn
# more](https://python.langchain.com/oss/python/langgraph/overview)\n\n[![Image 5:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=forma
# t&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhg
# eW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149
# e3836cc) ## Debug with LangSmith Gain deep visibility into complex agent behavior with visualization tools that
# trace execution paths, capture state transitions, and provide detailed runtime metrics. Learn
# more](https://python.langchain.com/langsmith/observability)\n\n* * *\n\n[Connect these
# docs](https://python.langchain.com/use-these-docs) to Claude, VSCode, and more via MCP for real-time
# answers.\n\n[Edit this page on
# GitHub](https://github.com/langchain-ai/docs/edit/main/src/oss/langchain/overview.mdx) or [file an
# issue](https://github.com/langchain-ai/docs/issues/new/choose).\n\nWas this page helpful?\n\nYes No\n\n[Install
# LangChain Next](https://python.langchain.com/oss/python/langchain/install)\n\nCtrl+I\n\n[Docs by LangChain home
# page![Image 6: light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 7: dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://python.langchain.com/)\n\n[github](h
# ttps://github.com/langchain-ai)[x](https://x.com/LangChain)[linkedin](https://www.linkedin.com/company/langchain)[y
# outube](https://www.youtube.com/@LangChain)\n\nResources\n\n[Forum](https://forum.langchain.com/)[Changelog](https:
# //changelog.langchain.com/)[LangChain Academy](https://academy.langchain.com/)[Contact
# Sales](https://www.langchain.com/contact-sales)\n\nCompany\n\n[Home](https://langchain.com/)[Trust
# Center](https://trust.langchain.com/)[Careers](https://langchain.com/careers)[Blog](https://blog.langchain.com/)\n\
# n[github](https://github.com/langchain-ai)[x](https://x.com/LangChain)[linkedin](https://www.linkedin.com/company/l
# angchain)[youtube](https://www.youtube.com/@LangChain)\n\n## Chat LangChain\n\n[](https://chat.langchain.com/ "Open
# chat.langchain.com in a new tab")'
#         },
#         {
#             'url': 'https://python.langchain.com/use-these-docs',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/langsmith/home',
#             'raw_content': '# LangChain overview - Docs by LangChain\n\n[Skip to main
# content](https://python.langchain.com/langsmith/home#content-area)\n\nJoin us May 13th & May 14th at Interrupt, the
# Agent Conference by LangChain. [Buy tickets >](https://interrupt.langchain.com/)\n\n[Docs by LangChain home
# page![Image 1: light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 2: dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://python.langchain.com/)![Image 3:
# https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3
# .us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png)Open source\n\nSearch...\n\n⌘K\n\n*
# [Ask AI](https://chat.langchain.com/)\n*   [GitHub](https://github.com/langchain-ai)\n*   [Try
# LangSmith](https://smith.langchain.com/)\n*   [Try
# LangSmith](https://smith.langchain.com/)\n\nSearch...\n\nNavigation\n\nLangChain overview\n\n[Deep
# Agents](https://python.langchain.com/oss/python/deepagents/overview)[LangChain](https://python.langchain.com/oss/py
# thon/langchain/overview)[LangGraph](https://python.langchain.com/oss/python/langgraph/overview)[Integrations](https
# ://python.langchain.com/oss/python/integrations/providers/overview)[Learn](https://python.langchain.com/oss/python/
# learn)[Reference](https://python.langchain.com/oss/python/reference/overview)[Contribute](https://python.langchain.
# com/oss/python/contributing/overview)\n\nPython\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/overview)\n\n##### Get started\n\n*
# [Install](https://python.langchain.com/oss/python/langchain/install)\n*
# [Quickstart](https://python.langchain.com/oss/python/langchain/quickstart)\n*
# [Changelog](https://docs.langchain.com/oss/python/releases/changelog)\n*
# [Philosophy](https://python.langchain.com/oss/python/langchain/philosophy)\n\n##### Core components\n\n*
# [Agents](https://python.langchain.com/oss/python/langchain/agents)\n*
# [Models](https://python.langchain.com/oss/python/langchain/models)\n*
# [Messages](https://python.langchain.com/oss/python/langchain/messages)\n*
# [Tools](https://python.langchain.com/oss/python/langchain/tools)\n*   [Short-term
# memory](https://python.langchain.com/oss/python/langchain/short-term-memory)\n*
# [Streaming](https://python.langchain.com/oss/python/langchain/streaming)\n*   [Structured
# output](https://python.langchain.com/oss/python/langchain/structured-output)\n\n##### Middleware\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/middleware/overview)\n*   [Prebuilt
# middleware](https://python.langchain.com/oss/python/langchain/middleware/built-in)\n*   [Custom
# middleware](https://python.langchain.com/oss/python/langchain/middleware/custom)\n\n##### Frontend\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/frontend/overview)\n*   Patterns  \n*   Integrations
# \n\n##### Advanced usage\n\n*   [Guardrails](https://python.langchain.com/oss/python/langchain/guardrails)\n*
# [Runtime](https://python.langchain.com/oss/python/langchain/runtime)\n*   [Context
# engineering](https://python.langchain.com/oss/python/langchain/context-engineering)\n*   [Model Context Protocol
# (MCP)](https://python.langchain.com/oss/python/langchain/mcp)\n*
# [Human-in-the-loop](https://python.langchain.com/oss/python/langchain/human-in-the-loop)\n*   Multi-agent  \n*
# [Retrieval](https://python.langchain.com/oss/python/langchain/retrieval)\n*   [Long-term
# memory](https://python.langchain.com/oss/python/langchain/long-term-memory)\n\n##### Agent development\n\n*
# [LangSmith Studio](https://python.langchain.com/oss/python/langchain/studio)\n*   Test  \n*   [Agent Chat
# UI](https://python.langchain.com/oss/python/langchain/ui)\n\n##### Deploy with LangSmith\n\n*
# [Deployment](https://python.langchain.com/oss/python/langchain/deploy)\n*
# [Observability](https://python.langchain.com/oss/python/langchain/observability)\n\nOn this page\n\n*   [Create an
# agent](https://python.langchain.com/langsmith/home#create-an-agent)\n*   [Core
# benefits](https://python.langchain.com/langsmith/home#core-benefits)\n\n# LangChain overview\n\nCopy
# page\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for any model or
# tool—so you can build agents that adapt as fast as the ecosystem evolves\n\nCopy page\n\n> ## Documentation
# Index\n> \n> \n> Fetch the complete documentation index at:
# [https://docs.langchain.com/llms.txt](https://docs.langchain.com/llms.txt)\n> \n> \n> Use this file to discover all
# available pages before exploring further.\n\nBuild completely custom agents and applications powered by LLMs in
# under 10 lines of code, with integrations for [OpenAI, Anthropic, Google, and
# more](https://python.langchain.com/oss/python/integrations/providers/overview). LangChain provides a prebuilt agent
# architecture and model integrations to help you get started quickly and seamlessly incorporate LLMs into your
# agents and applications.\n\n**LangChain vs. LangGraph vs. Deep Agents**Start with [Deep
# Agents](https://python.langchain.com/oss/python/deepagents/overview) for a “batteries-included” agent with features
# like automatic context compression, a virtual filesystem, and subagent-spawning. Deep Agents are built on LangChain
# [agents](https://python.langchain.com/oss/python/langchain/agents) which you can also use LangChain directly.Use
# [LangGraph](https://python.langchain.com/oss/python/langgraph/overview), our low-level orchestration framework, for
# advanced needs combining deterministic and agentic workflows.Use
# [LangSmith](https://python.langchain.com/langsmith/home) to trace, debug, and evaluate agents built with any of
# these frameworks. Follow the [tracing quickstart](https://python.langchain.com/langsmith/trace-with-langchain) to
# get set up.\n\n## [\u200b](https://python.langchain.com/langsmith/home#create-an-agent)\n\n Create an
# agent\n\nOpenAI\n\nGoogle Gemini\n\nClaude
# (Anthropic)\n\nOpenRouter\n\nFireworks\n\nBaseten\n\nOllama\n\nAzure\n\nAWS Bedrock\n\nHuggingFace\n\n```\n# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n    """Get weather for a given city."""\n    return f"It\'s always sunny in {city}!"\n\nagent =
# create_agent(\n    model="openai:gpt-5.4",\n    tools=[get_weather],\n    system_prompt="You are a helpful
# assistant",\n)\n\nresult = agent.invoke(\n    {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)\n```\n\nSee the [Installation
# instructions](https://python.langchain.com/oss/python/langchain/install) and [Quickstart
# guide](https://python.langchain.com/oss/python/langchain/quickstart) to get started building your own agents and
# applications with LangChain.\n\nUse [LangSmith](https://python.langchain.com/langsmith/home) to trace requests,
# debug agent behavior, and evaluate outputs. Set `LANGSMITH_TRACING=true` and your API key to get started.\n\n##
# [\u200b](https://python.langchain.com/langsmith/home#core-benefits)\n\n Core benefits\n\n## Standard model
# interface\n\nDifferent providers have unique APIs for interacting with models, including the format of responses.
# LangChain standardizes how you interact with models so that you can seamlessly swap providers and avoid
# lock-in.\n\nLearn more\n\n## Easy to use, highly flexible agent\n\nLangChain’s agent abstraction is designed to be
# easy to get started with, letting you build a simple agent in under 10 lines of code. But it also provides enough
# flexibility to allow you to do all the context engineering your heart desires.\n\nLearn more\n\n![Image 4:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-s
# jd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images
# /brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81)\n\n##
# Built on top of LangGraph\n\nLangChain’s agents are built on top of LangGraph. This allows us to take advantage of
# LangGraph’s durable execution, human-in-the-loop support, persistence, and more.\n\nLearn more\n\n![Image 5:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=forma
# t&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhg
# eW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149
# e3836cc)\n\n## Debug with LangSmith\n\nGain deep visibility into complex agent behavior with visualization tools
# that trace execution paths, capture state transitions, and provide detailed runtime metrics.\n\nLearn more\n\n* *
# *\n\n[Connect these docs](https://python.langchain.com/use-these-docs) to Claude, VSCode, and more via MCP for
# real-time answers.\n\n[Edit this page on
# GitHub](https://github.com/langchain-ai/docs/edit/main/src/oss/langchain/overview.mdx) or [file an
# issue](https://github.com/langchain-ai/docs/issues/new/choose).\n\nWas this page helpful?\n\nYes No\n\n[Install
# LangChain Next](https://python.langchain.com/oss/python/langchain/install)\n\n⌘I\n\n[Docs by LangChain home
# page![Image 6: light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 7: dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://python.langchain.com/)\n\n[github](h
# ttps://github.com/langchain-ai)[x](https://x.com/LangChain)[linkedin](https://www.linkedin.com/company/langchain)[y
# outube](https://www.youtube.com/@LangChain)\n\nResources\n\n[Forum](https://forum.langchain.com/)[Changelog](https:
# //changelog.langchain.com/)[LangChain Academy](https://academy.langchain.com/)[Contact
# Sales](https://www.langchain.com/contact-sales)\n\nCompany\n\n[Home](https://langchain.com/)[Trust
# Center](https://trust.langchain.com/)[Careers](https://langchain.com/careers)[Blog](https://blog.langchain.com/)\n\
# n[github](https://github.com/langchain-ai)[x](https://x.com/LangChain)[linkedin](https://www.linkedin.com/company/l
# angchain)[youtube](https://www.youtube.com/@LangChain)'
#         },
#         {
#             'url': 'https://python.langchain.com/langsmith/observability',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/learn',
#             'raw_content': '# LangChain overview - Docs by LangChain\n\n[Skip to main
# content](https://python.langchain.com/oss/python/learn#content-area)\n\nJoin us May 13th & May 14th at Interrupt,
# the Agent Conference by LangChain. [Buy tickets >](https://interrupt.langchain.com/)\n\n[Docs by LangChain home
# page![Image 1: light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 2: dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://python.langchain.com/)![Image 3:
# https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3
# .us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png)Open source\n\nSearch...\n\nCtrl K\n\n*
# [Ask AI](https://chat.langchain.com/)\n*   [GitHub](https://github.com/langchain-ai)\n*   [Try
# LangSmith](https://smith.langchain.com/)\n*   [Try
# LangSmith](https://smith.langchain.com/)\n\nSearch...\n\nNavigation\n\nLangChain overview\n\n[Deep
# Agents](https://python.langchain.com/oss/python/deepagents/overview)[LangChain](https://python.langchain.com/oss/py
# thon/langchain/overview)[LangGraph](https://python.langchain.com/oss/python/langgraph/overview)[Integrations](https
# ://python.langchain.com/oss/python/integrations/providers/overview)[Learn](https://python.langchain.com/oss/python/
# learn)[Reference](https://python.langchain.com/oss/python/reference/overview)[Contribute](https://python.langchain.
# com/oss/python/contributing/overview)\n\nPython\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/overview)\n\n##### Get started\n\n*
# [Install](https://python.langchain.com/oss/python/langchain/install)\n*
# [Quickstart](https://python.langchain.com/oss/python/langchain/quickstart)\n*
# [Changelog](https://docs.langchain.com/oss/python/releases/changelog)\n*
# [Philosophy](https://python.langchain.com/oss/python/langchain/philosophy)\n\n##### Core components\n\n*
# [Agents](https://python.langchain.com/oss/python/langchain/agents)\n*
# [Models](https://python.langchain.com/oss/python/langchain/models)\n*
# [Messages](https://python.langchain.com/oss/python/langchain/messages)\n*
# [Tools](https://python.langchain.com/oss/python/langchain/tools)\n*   [Short-term
# memory](https://python.langchain.com/oss/python/langchain/short-term-memory)\n*
# [Streaming](https://python.langchain.com/oss/python/langchain/streaming)\n*   [Structured
# output](https://python.langchain.com/oss/python/langchain/structured-output)\n\n##### Middleware\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/middleware/overview)\n*   [Prebuilt
# middleware](https://python.langchain.com/oss/python/langchain/middleware/built-in)\n*   [Custom
# middleware](https://python.langchain.com/oss/python/langchain/middleware/custom)\n\n##### Frontend\n\n*
# [Overview](https://python.langchain.com/oss/python/langchain/frontend/overview)\n*   Patterns  \n*   Integrations
# \n\n##### Advanced usage\n\n*   [Guardrails](https://python.langchain.com/oss/python/langchain/guardrails)\n*
# [Runtime](https://python.langchain.com/oss/python/langchain/runtime)\n*   [Context
# engineering](https://python.langchain.com/oss/python/langchain/context-engineering)\n*   [Model Context Protocol
# (MCP)](https://python.langchain.com/oss/python/langchain/mcp)\n*
# [Human-in-the-loop](https://python.langchain.com/oss/python/langchain/human-in-the-loop)\n*   Multi-agent  \n*
# [Retrieval](https://python.langchain.com/oss/python/langchain/retrieval)\n*   [Long-term
# memory](https://python.langchain.com/oss/python/langchain/long-term-memory)\n\n##### Agent development\n\n*
# [LangSmith Studio](https://python.langchain.com/oss/python/langchain/studio)\n*   Test  \n*   [Agent Chat
# UI](https://python.langchain.com/oss/python/langchain/ui)\n\n##### Deploy with LangSmith\n\n*
# [Deployment](https://python.langchain.com/oss/python/langchain/deploy)\n*
# [Observability](https://python.langchain.com/oss/python/langchain/observability)\n\nOn this page\n\n*   [Create an
# agent](https://python.langchain.com/oss/python/learn#create-an-agent)\n*   [Core
# benefits](https://python.langchain.com/oss/python/learn#core-benefits)\n\n# LangChain overview\n\nCopy
# page\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for any model or
# tool—so you can build agents that adapt as fast as the ecosystem evolves\n\nCopy page\n\n> ## Documentation
# Index\n> \n> \n> Fetch the complete documentation index at:
# [https://docs.langchain.com/llms.txt](https://docs.langchain.com/llms.txt)\n> \n> \n> Use this file to discover all
# available pages before exploring further.\n\nBuild completely custom agents and applications powered by LLMs in
# under 10 lines of code, with integrations for [OpenAI, Anthropic, Google, and
# more](https://python.langchain.com/oss/python/integrations/providers/overview). LangChain provides a prebuilt agent
# architecture and model integrations to help you get started quickly and seamlessly incorporate LLMs into your
# agents and applications.\n\n**LangChain vs. LangGraph vs. Deep Agents**Start with [Deep
# Agents](https://python.langchain.com/oss/python/deepagents/overview) for a “batteries-included” agent with features
# like automatic context compression, a virtual filesystem, and subagent-spawning. Deep Agents are built on LangChain
# [agents](https://python.langchain.com/oss/python/langchain/agents) which you can also use LangChain directly.Use
# [LangGraph](https://python.langchain.com/oss/python/langgraph/overview), our low-level orchestration framework, for
# advanced needs combining deterministic and agentic workflows.\n\n##
# [\u200b](https://python.langchain.com/oss/python/learn#create-an-agent)\n\n Create an agent\n\nOpenAI\n\nGoogle
# Gemini\n\nClaude (Anthropic)\n\nOpenRouter\n\nFireworks\n\nBaseten\n\nOllama\n\nAzure\n\nAWS
# Bedrock\n\nHuggingFace\n\n```\n# pip install -qU langchain "langchain[openai]"\nfrom langchain.agents import
# create_agent\n\ndef get_weather(city: str) -> str:\n    """Get weather for a given city."""\n    return f"It\'s
# always sunny in {city}!"\n\nagent = create_agent(\n    model="openai:gpt-5.4",\n    tools=[get_weather],\n
# system_prompt="You are a helpful assistant",\n)\n\nresult = agent.invoke(\n    {"messages": [{"role": "user",
# "content": "What\'s the weather in San Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)\n```\n\nSee
# the [Installation instructions](https://python.langchain.com/oss/python/langchain/install) and [Quickstart
# guide](https://python.langchain.com/oss/python/langchain/quickstart) to get started building your own agents and
# applications with LangChain.\n\nUse [LangSmith](https://python.langchain.com/langsmith/home) to trace requests,
# debug agent behavior, and evaluate outputs. Set `LANGSMITH_TRACING=true` and your API key to get started.\n\n##
# [\u200b](https://python.langchain.com/oss/python/learn#core-benefits)\n\n Core benefits\n\n## [Standard model
# interface Different providers have unique APIs for interacting with models, including the format of responses.
# LangChain standardizes how you interact with models so that you can seamlessly swap providers and avoid lock-in.
# Learn more](https://python.langchain.com/oss/python/langchain/models)\n\n## [Easy to use, highly flexible agent
# LangChain’s agent abstraction is designed to be easy to get started with, letting you build a simple agent in under
# 10 lines of code. But it also provides enough flexibility to allow you to do all the context engineering your heart
# desires. Learn more](https://python.langchain.com/oss/python/langchain/agents)\n\n[![Image 4:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-s
# jd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images
# /brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81) ## Built
# on top of LangGraph LangChain’s agents are built on top of LangGraph. This allows us to take advantage of
# LangGraph’s durable execution, human-in-the-loop support, persistence, and more. Learn
# more](https://python.langchain.com/oss/python/langgraph/overview)\n\n[![Image 5:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=forma
# t&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhg
# eW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149
# e3836cc) ## Debug with LangSmith Gain deep visibility into complex agent behavior with visualization tools that
# trace execution paths, capture state transitions, and provide detailed runtime metrics. Learn
# more](https://python.langchain.com/langsmith/observability)\n\n* * *\n\n[Connect these
# docs](https://python.langchain.com/use-these-docs) to Claude, VSCode, and more via MCP for real-time
# answers.\n\n[Edit this page on
# GitHub](https://github.com/langchain-ai/docs/edit/main/src/oss/langchain/overview.mdx) or [file an
# issue](https://github.com/langchain-ai/docs/issues/new/choose).\n\nWas this page helpful?\n\nYes No\n\n[Install
# LangChain Next](https://python.langchain.com/oss/python/langchain/install)\n\nCtrl+I\n\n[Docs by LangChain home
# page![Image 6: light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 7: dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://python.langchain.com/)\n\n[github](h
# ttps://github.com/langchain-ai)[x](https://x.com/LangChain)[linkedin](https://www.linkedin.com/company/langchain)[y
# outube](https://www.youtube.com/@LangChain)\n\nResources\n\n[Forum](https://forum.langchain.com/)[Changelog](https:
# //changelog.langchain.com/)[LangChain Academy](https://academy.langchain.com/)[Contact
# Sales](https://www.langchain.com/contact-sales)\n\nCompany\n\n[Home](https://langchain.com/)[Trust
# Center](https://trust.langchain.com/)[Careers](https://langchain.com/careers)[Blog](https://blog.langchain.com/)\n\
# n[github](https://github.com/langchain-ai)[x](https://x.com/LangChain)[linkedin](https://www.linkedin.com/company/l
# angchain)[youtube](https://www.youtube.com/@LangChain)\n\n## Chat LangChain\n\n[](https://chat.langchain.com/ "Open
# chat.langchain.com in a new tab")'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/langchain/philosophy',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/langchain/agents',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# ...
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/langchain/structured-output',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/langchain/observability',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/langchain/deploy',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/langchain/studio',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         }
#     ],
#     'response_time': 0.18,
#     'request_id': '07dc0259-8b10-43a1-9326-0d730024b8a3'
# }

# %% [markdown]
# # Now display the formatted results nicely

# %%
console.print(f"\nResults Without Instructions: {len(basic_results)} pages", style="cyan")
console.print("   Mix of all content types from LangChain docs")
console.print("   No filtering - everything from the crawled sections")
console.print("   Requires manual work to find specific content")

console.print("\nSample Results from Basic Crawl (No Filtering):\n", style="cyan")

for i, result in enumerate(basic_results[:3], 1):  # Show first 3 results
    url = result.get("url", "No URL")
    content = result.get("raw_content", "No content")[:150] + "..."
    
    panel_content = f"""URL: {url}

Content Preview:
{content}"""
    
    console.print(Panel(
        panel_content,
        title=f"{i}. {url}",
        border_style="blue"
    ))
    print()

console.print(f"... and {len(basic_results) - 3} more mixed results", style="italic cyan")
console.print("Note: Mixed content types - guides, integrations, concepts, etc.", style="cyan")
# Out:
# Results Without Instructions: 21 pages
#    Mix of all content types from LangChain docs
#    No filtering - everything from the crawled sections
#    Requires manual work to find specific content
# Sample Results from Basic Crawl (No Filtering):
# ╭─────────────────────────────────────── 1. https://python.langchain.com/ ────────────────────────────────────────╮
# │ URL: https://python.langchain.com/                                                                              │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy tickets                       │
# │ >](https://interrupt.langchain.com/)                                                                            │
# │                                                                                                                 │
# │ !(https://...                                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────── 2. https://python.langchain.com/$%7BCHAT_APP_URL%7D ──────────────────────────────╮
# │ URL: https://python.langchain.com/$%7BCHAT_APP_URL%7D                                                           │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ # LangChain overview - Docs by LangChain                                                                        │
# │                                                                                                                 │
# │ [Skip to main content](https://python.langchain.com/$%7BCHAT_APP_URL%7D#content-area)                           │
# │                                                                                                                 │
# │ Join us May 13th & Ma...                                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────── 3. https://python.langchain.com/use-these-docs ─────────────────────────────────╮
# │ URL: https://python.langchain.com/use-these-docs                                                                │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy tickets                       │
# │ >](https://interrupt.langchain.com/)                                                                            │
# │                                                                                                                 │
# │ !(https://...                                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ... and 18 more mixed results
# Note: Mixed content types - guides, integrations, concepts, etc.

# %% [markdown]
# ## Demo 2: Crawl With Instructions
#
# Use specific instructions to improve the quality and relevance of crawl results. Instructions can dramatically improve targeting and filtering.

# %%
instructions = "Find all pages about ai agents"

console.print(Panel.fit(
    f"Target: {target_url} (same as Demo 1)\nInstructions: {instructions}\nType: Specific, action-oriented\nMax Depth: 3\nExtract Depth: advanced",
    title="Demo 2: Crawl With Instructions", 
    border_style="green"
))

console.print("Starting crawl with instructions...", style="green")
console.print("Instructions will guide the AI to target specific content", style="italic")
# Out:
# ╭─────────── Demo 2: Crawl With Instructions ────────────╮
# │ Target: https://python.langchain.com/ (same as Demo 1) │
# │ Instructions: Find all pages about ai agents           │
# │ Type: Specific, action-oriented                        │
# │ Max Depth: 3                                           │
# │ Extract Depth: advanced                                │
# ╰────────────────────────────────────────────────────────╯
# Starting crawl with instructions...
# Instructions will guide the AI to target specific content

# %%
# Execute the crawl with instructions
result_with_instructions = tavily_crawl.invoke({
    "url": target_url,
    "instructions": instructions,
    "max_depth": 3,
    "extract_depth": "advanced"
})

# Show raw output immediately
console.print("\nRaw TavilyCrawl Output:", style="yellow")
console.print(result_with_instructions)

console.print("\nCrawl with instructions completed", style="green")

# Show the results of instruction-based filtering
results_with_instructions = result_with_instructions.get("results", [])
# Out:
# Raw TavilyCrawl Output:
# {
#     'base_url': 'https://python.langchain.com/',
#     'results': [
#         {
#             'url': 'https://docs.langchain.com/',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\n## Documentation Index\n\nFetch the
# complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to discover all available
# pages before exploring further.\n\n# Documentation\n\n##
# LangSmith\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n##
# Observability\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/evaluation-icon-dark.png?fi
# t=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=4918f932fff73a33d6a24e2fcf68f6a4](https://mintcdn.com/langchain-5e9cc07
# a/nQm-sjd_MByLhgeW/images/brand/evaluation-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=4918f932fff7
# 3a33d6a24e2fcf68f6a4)\n\n##
# Evaluation\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/prompt-engineering-icon.png?fi
# t=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=eaa7ac978bebe5a7cd84d8eeaaef84c2](https://mintcdn.com/langchain-5e9cc07
# a/nQm-sjd_MByLhgeW/images/brand/prompt-engineering-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=eaa7ac978
# bebe5a7cd84d8eeaaef84c2)\n\n## Prompt
# Engineering\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/deployment-icon-dark.png?fit=
# max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=024e3712d388bfa55f4f160cc9d6a85b](https://mintcdn.com/langchain-5e9cc07a/
# nQm-sjd_MByLhgeW/images/brand/deployment-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=024e3712d388bf
# a55f4f160cc9d6a85b)\n\n## Deployment\n\n## LangSmith
# Fleet\n\n![https://mintcdn.com/langchain-5e9cc07a/_jaNDz0QENsVkDXY/images/brand/fleet-icon-dark.png?fit=max&auto=fo
# rmat&n=_jaNDz0QENsVkDXY&q=85&s=98e3bbb4ae01325a8ff867e80681778f](https://mintcdn.com/langchain-5e9cc07a/_jaNDz0QENs
# VkDXY/images/brand/fleet-icon-dark.png?fit=max&auto=format&n=_jaNDz0QENsVkDXY&q=85&s=98e3bbb4ae01325a8ff867e8068177
# 8f)\n\n## Fleet\n\n## Open source agent
# frameworks\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/deep-agents-icon.png?fit=max&a
# uto=format&n=nQm-sjd_MByLhgeW&q=85&s=1cc68f66a9e7550331cc0875f1ba53af](https://mintcdn.com/langchain-5e9cc07a/nQm-s
# jd_MByLhgeW/images/brand/deep-agents-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=1cc68f66a9e7550331cc087
# 5f1ba53af)\n\n## Deep Agents
# (Python)\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-icon.png?fit=max&auto=
# format&n=nQm-sjd_MByLhgeW&q=85&s=663b30f85baf99ad708b97e05da2a5a4](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_M
# ByLhgeW/images/brand/langchain-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=663b30f85baf99ad708b97e05da2a
# 5a4)\n\n## LangChain
# (Python)\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=
# format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_M
# ByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99
# f81)\n\n## LangGraph
# (Python)\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/deep-agents-icon.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=1cc68f66a9e7550331cc0875f1ba53af](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd
# _MByLhgeW/images/brand/deep-agents-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=1cc68f66a9e7550331cc0875f
# 1ba53af)\n\n## Deep Agents
# (TypeScript)\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-icon.png?fit=max&a
# uto=format&n=nQm-sjd_MByLhgeW&q=85&s=663b30f85baf99ad708b97e05da2a5a4](https://mintcdn.com/langchain-5e9cc07a/nQm-s
# jd_MByLhgeW/images/brand/langchain-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=663b30f85baf99ad708b97e05
# da2a5a4)\n\n## LangChain
# (TypeScript)\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&a
# uto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-s
# jd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedb
# fd99f81)\n\n## LangGraph (TypeScript)\n\n## Get started\n\n## Build your first agent with LangChain\n\n## Sign up
# for LangSmith\n\n## Build an advanced agent with LangGraph\n\n## Enroll in LangChain Academy\n\n## Additional
# resources\n\n## Community forum\n\n## Community Slack\n\n## Support portal\n\n## LangSmith status'
#         },
#         {
#             'url': 'https://docs.langchain.com/langsmith/home',
#             'raw_content': '# LangSmith docs - Docs by LangChain\n\n[Skip to main
# content](https://docs.langchain.com/langsmith/home#content-area)\n\nJoin us May 13th & May 14th at Interrupt, the
# Agent Conference by LangChain. [Buy tickets >](https://interrupt.langchain.com/)\n\n[Docs by LangChain home
# page![Image 1: light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 2: dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://docs.langchain.com/)![Image 3:
# https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/observability-icon-dark.png](https://mi
# ntlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/observability-icon-dark.png)LangSmith\n\nSearch..
# .\n\nCtrl K\n\n*   [Ask AI](https://chat.langchain.com/)\n*   [GitHub](https://github.com/langchain-ai)\n*   [Try
# LangSmith](https://smith.langchain.com/)\n*   [Try
# LangSmith](https://smith.langchain.com/)\n\nSearch...\n\nNavigation\n\nLangSmith docs\n\n[Get
# started](https://docs.langchain.com/langsmith/home)[Observability](https://docs.langchain.com/langsmith/observabili
# ty)[Evaluation](https://docs.langchain.com/langsmith/evaluation)[Prompt
# engineering](https://docs.langchain.com/langsmith/prompt-engineering)[Agent
# deployment](https://docs.langchain.com/langsmith/deployment)[Platform
# setup](https://docs.langchain.com/langsmith/platform-setup)[Reference](https://docs.langchain.com/langsmith/referen
# ce)\n\n*   [Overview](https://docs.langchain.com/langsmith/home)\n\n*   [Create an account and API
# key](https://docs.langchain.com/langsmith/create-account-api-key)\n\n*
# [Integrations](https://docs.langchain.com/langsmith/integrations)\n\n*
# [Plans](https://langchain.com/pricing)\n\n*   [Enterprise
# features](https://docs.langchain.com/langsmith/enterprise)\n\n##### Account administration\n\n*
# [Overview](https://docs.langchain.com/langsmith/administration-overview)\n*   Workspace setup  \n*   Users & access
# control  \n*   Billing & usage  \n*   [Manage organizations using the
# API](https://docs.langchain.com/langsmith/manage-organization-by-api)\n*   [Audit
# logs](https://docs.langchain.com/langsmith/audit-logs)\n\n##### Tools\n\n*   [Polly AI
# assistant](https://docs.langchain.com/langsmith/polly)\n*
# [CLI](https://docs.langchain.com/langsmith/langsmith-cli)\n*
# [Skills](https://docs.langchain.com/langsmith/skills)\n*    Sandboxes Private preview  \n\n##### Additional
# resources\n\n*    Data & compliance  \n*    FAQ  \n*   [LangSmith status](https://status.smith.langchain.com/)\n\n#
# LangSmith docs\n\nCopy page\n\nCopy page\n\n> ## Documentation Index\n> \n> \n> Fetch the complete documentation
# index at: [https://docs.langchain.com/llms.txt](https://docs.langchain.com/llms.txt)\n> \n> \n> Use this file to
# discover all available pages before exploring further.\n\n**LangSmith is a framework-agnostic platform for
# building, debugging, and deploying AI agents and LLM applications.** Trace requests, evaluate outputs, test
# prompts, and manage deployments all in one place, with your agent stack.\n##
# [\u200b](https://docs.langchain.com/langsmith/home#get-started)\n\nGet
# started\n\n[](https://docs.langchain.com/langsmith/home#)\n\nCreate an account\n\nSign up at
# [smith.langchain.com](https://smith.langchain.com/) (no credit card required). You can log in with **Google**,
# **GitHub**, or **email**.\n\n[](https://docs.langchain.com/langsmith/home#)\n\nCreate an API key\n\nGo to your
# [Settings page](https://smith.langchain.com/settings) → **API Keys** → **Create API Key**. Copy the key and save it
# securely.\n\n[](https://docs.langchain.com/langsmith/home#)\n\nChoose your integration\n\nLangSmith works with many
# frameworks and providers. Browse [available integrations](https://docs.langchain.com/langsmith/integrations) to
# connect your stack.\n\nOnce your account and API key are ready, choose a quickstart to begin building with
# LangSmith:\n\n[![Image 4:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=forma
# t&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhg
# eW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149
# e3836cc) ## Observability Gain visibility into every step your application takes to debug faster and improve
# reliability. Start tracing](https://docs.langchain.com/langsmith/observability-quickstart)\n\n[![Image 5:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/evaluation-icon-dark.png?fit=max&auto=format&n
# =nQm-sjd_MByLhgeW&q=85&s=4918f932fff73a33d6a24e2fcf68f6a4](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/
# images/brand/evaluation-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=4918f932fff73a33d6a24e2fcf68f6a
# 4) ## Evaluation Measure and track quality over time to ensure your AI applications are consistent and trustworthy.
# Evaluate your app](https://docs.langchain.com/langsmith/evaluation-quickstart)\n\n[![Image 6:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/deployment-icon-dark.png?fit=max&auto=format&n
# =nQm-sjd_MByLhgeW&q=85&s=024e3712d388bfa55f4f160cc9d6a85b](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/
# images/brand/deployment-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=024e3712d388bfa55f4f160cc9d6a85
# b) ## Deployment Deploy your agents as Agent Servers, ready to scale in production. Deploy your
# agents](https://docs.langchain.com/langsmith/deployment)\n\n##
# [\u200b](https://docs.langchain.com/langsmith/home#more-ways-to-build)\n\nMore ways to build\n\n[![Image 7:
# https://mintcdn.com/langchain-5e9cc07a/_jaNDz0QENsVkDXY/images/brand/fleet-icon-dark.png?fit=max&auto=format&n=_jaN
# Dz0QENsVkDXY&q=85&s=98e3bbb4ae01325a8ff867e80681778f](https://mintcdn.com/langchain-5e9cc07a/_jaNDz0QENsVkDXY/image
# s/brand/fleet-icon-dark.png?fit=max&auto=format&n=_jaNDz0QENsVkDXY&q=85&s=98e3bbb4ae01325a8ff867e80681778f) ##
# Fleet Design and deploy AI agents visually without writing code. Build an
# agent](https://docs.langchain.com/langsmith/fleet/index)\n\n[![Image 8:
# https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/prompt-engineering-icon.png?fit=max&auto=forma
# t&n=nQm-sjd_MByLhgeW&q=85&s=eaa7ac978bebe5a7cd84d8eeaaef84c2](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhg
# eW/images/brand/prompt-engineering-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=eaa7ac978bebe5a7cd84d8eea
# aef84c2) ## Prompt engineering Iterate on prompts with built-in versioning and collaboration to ship improvements
# faster. Test your prompts](https://docs.langchain.com/langsmith/prompt-engineering-quickstart)\n\n## [LangSmith CLI
# Query and manage traces, datasets, experiments, and more from the terminal. Use the
# CLI](https://docs.langchain.com/langsmith/langsmith-cli)\n\n## [Studio Use a visual interface to design, test, and
# refine applications end-to-end. Develop with Studio](https://docs.langchain.com/langsmith/quick-start-studio)\n\n##
# [\u200b](https://docs.langchain.com/langsmith/home#infrastructure)\n\nInfrastructure\n\n## [Platform setup Use
# LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance
# needs. Choose how to set up LangSmith](https://docs.langchain.com/langsmith/platform-setup)\n\n## [Security &
# compliance LangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR
# compliance. [Meet with our team](https://www.langchain.com/contact-sales) to learn more or visit our [Trust
# Center](https://trust.langchain.com/). Visit Trust Center](https://trust.langchain.com/)\n\n##
# [\u200b](https://docs.langchain.com/langsmith/home#workflow)\n\nWorkflow\n\nLangSmith combines observability,
# evaluation, deployment, and platform setup in one integrated workflow—from local development to production.![Image
# 9: Diagram showing how LangSmith integrates observability, evaluation, deployment, and platform setup in a single
# workflow from development to
# production.](https://mintcdn.com/langchain-5e9cc07a/ihKLTR9qUJ2_xg3v/langsmith/images/overview-light.png?fit=max&au
# to=format&n=ihKLTR9qUJ2_xg3v&q=85&s=43b537cc73859d51521b6d78a5802b15)![Image 10: Diagram showing how LangSmith
# integrates observability, evaluation, deployment, and platform setup in a single workflow from development to
# production.](https://mintcdn.com/langchain-5e9cc07a/ihKLTR9qUJ2_xg3v/langsmith/images/overview-dark.png?fit=max&aut
# o=format&n=ihKLTR9qUJ2_xg3v&q=85&s=fa519fc59d872d67ae282aac499ad2aa)\n\n* * *\n\n[Connect these
# docs](https://docs.langchain.com/use-these-docs) to Claude, VSCode, and more via MCP for real-time
# answers.\n\n[Edit this page on GitHub](https://github.com/langchain-ai/docs/edit/main/src/langsmith/home.mdx) or
# [file an issue](https://github.com/langchain-ai/docs/issues/new/choose).\n\nWas this page helpful?\n\nYes
# No\n\n[Create an account and API key
# Next](https://docs.langchain.com/langsmith/create-account-api-key)\n\nCtrl+I\n\n[Docs by LangChain home page![Image
# 11: light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)![Image 12: dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)](https://docs.langchain.com/)\n\n[github](htt
# ps://github.com/langchain-ai)[x](https://x.com/LangChain)[linkedin](https://www.linkedin.com/company/langchain)[you
# tube](https://www.youtube.com/@LangChain)\n\nResources\n\n[Forum](https://forum.langchain.com/)[Changelog](https://
# changelog.langchain.com/)[LangChain Academy](https://academy.langchain.com/)[Contact
# Sales](https://www.langchain.com/contact-sales)\n\nCompany\n\n[Home](https://langchain.com/)[Trust
# Center](https://trust.langchain.com/)[Careers](https://langchain.com/careers)[Blog](https://blog.langchain.com/)\n\
# n[github](https://github.com/langchain-ai)[x](https://x.com/LangChain)[linkedin](https://www.linkedin.com/company/l
# angchain)[youtube](https://www.youtube.com/@LangChain)\n\n## Chat LangChain\n\n[](https://chat.langchain.com/ "Open
# chat.langchain.com in a new tab")\n\n![Image 13: Diagram showing how LangSmith integrates observability,
# evaluation, deployment, and platform setup in a single workflow from development to
# production.](https://mintcdn.com/langchain-5e9cc07a/ihKLTR9qUJ2_xg3v/langsmith/images/overview-light.png?w=1100&fit
# =max&auto=format&n=ihKLTR9qUJ2_xg3v&q=85&s=fb9e6523b45e6ae63d78da5818b7894e)'
#         },
#         {
#             'url': 'https://docs.langchain.com/oss/python/deepagents/overview',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy
# tickets >\n\nlight logo\ndark logo\n\nPython\n\n##### Get started\n\n##### Deployment\n\n##### Core
# capabilities\n\n##### Frontend\n\n##### Protocols\n\n##### Command line interface\n\n# Deep Agents
# overview\n\nBuild agents that can plan, use subagents, and leverage file systems for complex tasks\n\n##
# Documentation Index\n\nFetch the complete documentation index at: \n\nUse this file to discover all available pages
# before exploring further.\n\n`deepagents`\n`deepagents`\n`deepagents`\n\n## \u200b Create a deep agent\n\n`# pip
# install -qU deepagents langchain-google-genai\nfrom deepagents import create_deep_agent\n\ndef get_weather(city:
# str) -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!" [...] agent =
# create_deep_agent(\n model="google_genai:gemini-3.1-pro-preview",\n tools=[get_weather],\n system_prompt="You are a
# helpful assistant",\n)\n\n# Run the agent\nagent.invoke(\n {"messages": [{"role": "user", "content": "what is the
# weather in sf"}]}\n)`\n`# pip install -qU deepagents langchain-openai\nfrom deepagents import
# create_deep_agent\n\ndef get_weather(city: str) -> str:\n """Get weather for a given city."""\n return f"It\'s
# always sunny in {city}!"\n\nagent = create_deep_agent(\n model="openai:gpt-5.4",\n tools=[get_weather],\n
# system_prompt="You are a helpful assistant",\n)\n\n# Run the agent\nagent.invoke(\n {"messages": [{"role": "user",
# "content": "what is the weather in sf"}]}\n)`\n`# pip install -qU deepagents langchain-anthropic\nfrom deepagents
# import create_deep_agent [...] ## \u200b Core capabilities\n\n## Planning and task
# decomposition\n\n`write_todos`\n\n## Context management\n\n`ls`\n`read_file`\n`write_file`\n`edit_file`\n\n## Shell
# execution\n\n`execute`\n\n## Pluggable filesystem backends\n\n## Subagent spawning\n\n`task`\n\n## Long-term
# memory\n\n## Filesystem permissions\n\n## Human-in-the-loop\n\n## Skills\n\n## Smart defaults\n\n## \u200b Get
# started\n\n## Quickstart\n\n## Customization\n\n## Models\n\n## Backends\n\n## Sandboxes\n\n## Permissions\n\n##
# Human-in-the-loop\n\n## CLI\n\n## ACP\n\n## Reference\n\n`deepagents`\n\nWas this page helpful?\n\nlight logo\ndark
# logo\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/langsmith/observability',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/deepagents/overview',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/langchain/agents',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         },
#         {
#             'url': 'https://python.langchain.com/oss/python/langchain/ui',
#             'raw_content': 'Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy
# tickets >](https://interrupt.langchain.com/)\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n![https://mintlify.s3.us-west-1.amazonaws.co
# m/langchain-5e9cc07a/images/brand/langchain-icon.png](https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07
# a/images/brand/langchain-icon.png)\n\nPython\n\n##### Get started\n\n##### Core components\n\n#####
# Middleware\n\n##### Frontend\n\n##### Advanced usage\n\n##### Agent development\n\n##### Deploy with LangSmith\n\n#
# LangChain overview\n\nLangChain is an open source framework with a prebuilt agent architecture and integrations for
# any model or tool—so you can build agents that adapt as fast as the ecosystem evolves\n\n## Documentation
# Index\n\nFetch the complete documentation index at: <https://docs.langchain.com/llms.txt>\n\nUse this file to
# discover all available pages before exploring further.\n\n## [\u200b](#create-an-agent) Create an agent\n\n`# pip
# install -qU langchain "langchain[openai]"\nfrom langchain.agents import create_agent\n\ndef get_weather(city: str)
# -> str:\n """Get weather for a given city."""\n return f"It\'s always sunny in {city}!"\n\nagent = create_agent(\n
# model="openai:gpt-5.4",\n tools=[get_weather],\n system_prompt="You are a helpful assistant",\n)\n\nresult =
# agent.invoke(\n {"messages": [{"role": "user", "content": "What\'s the weather in San
# Francisco?"}]}\n)\nprint(result["messages"][-1].content_blocks)`\n`LANGSMITH_TRACING=true`\n\n##
# [\u200b](#core-benefits) Core benefits\n\n## Standard model interface\n\n## Easy to use, highly flexible
# agent\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=for
# mat&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByL
# hgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81
# )\n\n## Built on top of
# LangGraph\n\n![https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit
# =max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc](https://mintcdn.com/langchain-5e9cc07a
# /nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto=format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca
# 2a5e4ca78d30149e3836cc)\n\n## Debug with LangSmith\n\nWas this page helpful?\n\n![light
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut
# o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)\n![dark
# logo](https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au
# to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)\n\nResources\n\nCompany'
#         }
#     ],
#     'response_time': 3.91,
#     'request_id': '29723314-654a-4315-b155-e490981e8d42'
# }
# Crawl with instructions completed

# %%
# Display the targeted agent documentation found
console.print("\nLangChain Agent Documentation Found:\n", style="green")

for i, result in enumerate(results_with_instructions, 1):
    url = result.get("url", "No URL")
    content = result.get("raw_content", "No content")[:200] + "..."
    
    panel_content = f"""URL: {url}

Content Preview:
{content}"""
    
    console.print(Panel(
        panel_content,
        title=f"{i}. {url}",
        border_style="green"
    ))
    print()

console.print("Note: All results are specifically about agents in LangChain", style="green")
# Out:
# LangChain Agent Documentation Found:
# ╭──────────────────────────────────────── 1. https://docs.langchain.com/ ─────────────────────────────────────────╮
# │ URL: https://docs.langchain.com/                                                                                │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy tickets                       │
# │ >](https://interrupt.langchain.com/)                                                                            │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/im...                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────── 2. https://docs.langchain.com/langsmith/home ──────────────────────────────────╮
# │ URL: https://docs.langchain.com/langsmith/home                                                                  │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ # LangSmith docs - Docs by LangChain                                                                            │
# │                                                                                                                 │
# │ [Skip to main content](https://docs.langchain.com/langsmith/home#content-area)                                  │
# │                                                                                                                 │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy ...                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────── 3. https://docs.langchain.com/oss/python/deepagents/overview ──────────────────────────╮
# │ URL: https://docs.langchain.com/oss/python/deepagents/overview                                                  │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >                      │
# │                                                                                                                 │
# │ light logo                                                                                                      │
# │ dark logo                                                                                                       │
# │                                                                                                                 │
# │ Python                                                                                                          │
# │                                                                                                                 │
# │ ##### Get started                                                                                               │
# │                                                                                                                 │
# │ ##### Deployment                                                                                                │
# │                                                                                                                 │
# │ ##### Core capabilities                                                                                         │
# │                                                                                                                 │
# │ ##### Frontend                                                                                                  │
# │                                                                                                                 │
# │ ...                                                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────── 4. https://python.langchain.com/langsmith/observability ────────────────────────────╮
# │ URL: https://python.langchain.com/langsmith/observability                                                       │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy tickets                       │
# │ >](https://interrupt.langchain.com/)                                                                            │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/im...                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────── 5. https://python.langchain.com/oss/python/deepagents/overview ─────────────────────────╮
# │ URL: https://python.langchain.com/oss/python/deepagents/overview                                                │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy tickets                       │
# │ >](https://interrupt.langchain.com/)                                                                            │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/im...                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────── 6. https://python.langchain.com/oss/python/langchain/agents ──────────────────────────╮
# │ URL: https://python.langchain.com/oss/python/langchain/agents                                                   │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy tickets                       │
# │ >](https://interrupt.langchain.com/)                                                                            │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/im...                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────── 7. https://python.langchain.com/oss/python/langchain/ui ────────────────────────────╮
# │ URL: https://python.langchain.com/oss/python/langchain/ui                                                       │
# │                                                                                                                 │
# │ Content Preview:                                                                                                │
# │ Join us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. [Buy tickets                       │
# │ >](https://interrupt.langchain.com/)                                                                            │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/im...                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Note: All results are specifically about agents in LangChain

# %% [markdown]
# ## Comparison of Both Approaches
#
# Compare both approaches to understand the impact of instruction quality.

# %%
# Create comparison table
comparison_table = Table(title="TavilyCrawl: Instruction Quality Comparison")
comparison_table.add_column("Approach", style="cyan", no_wrap=True)
comparison_table.add_column("Instructions", style="yellow")
comparison_table.add_column("Pages Found", style="blue")
comparison_table.add_column("Content Quality", style="green")
comparison_table.add_column("Usefulness", style="red")

comparison_table.add_row(
    "No Instructions",
    "None (baseline)",
    f"{len(basic_results)}",
    "Mixed (all types)",
    "Low (requires filtering)"
)

comparison_table.add_row(
    "With Instructions",
    instructions,
    f"{len(results_with_instructions)}",
    "Highly targeted",
    "High (ready to use)"
)

console.print(comparison_table)

console.print("\nKey Observations:", style="blue")
console.print("   No instructions return everything, requiring manual filtering")
console.print("   Instructions provide highly targeted, ready-to-use results")
console.print("   Best practice: Use specific, action-oriented instructions")

console.print(f"\nEfficiency with Instructions:", style="green")
console.print(f"   Filtering efficiency: {((len(basic_results) - len(results_with_instructions)) / len(basic_results) * 100):.1f}% reduction in noise")
console.print("   Time saved: No manual post-processing required")
console.print("   AI-powered: Intelligent path selection and content filtering")
# Out:
#                                     TavilyCrawl: Instruction Quality Comparison
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Approach          ┃ Instructions                   ┃ Pages Found ┃ Content Quality   ┃ Usefulness               ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ No Instructions   │ None (baseline)                │ 21          │ Mixed (all types) │ Low (requires filtering) │
# │ With Instructions │ Find all pages about ai agents │ 7           │ Highly targeted   │ High (ready to use)      │
# └───────────────────┴────────────────────────────────┴─────────────┴───────────────────┴──────────────────────────┘
# Key Observations:
#    No instructions return everything, requiring manual filtering
#    Instructions provide highly targeted, ready-to-use results
#    Best practice: Use specific, action-oriented instructions
# Efficiency with Instructions:
#    Filtering efficiency: 66.7% reduction in noise
#    Time saved: No manual post-processing required
#    AI-powered: Intelligent path selection and content filtering
